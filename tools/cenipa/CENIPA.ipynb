# %%
import pandas as pd
import pandera as pa

# %%
cenipa_dataset = "../../datasets/cenipa/ocorrencia_2010_2020.csv"

# %%
df = pd.read_csv(cenipa_dataset, 
                 delimiter=";", 
                 parse_dates=["ocorrencia_dia"],
                 dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
# [5 rows x 22 columns]

# %% [markdown]
# - df.dtypes;
# - df.ocorrencia_dia.dt.month;

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# total_recomendacoes                        int64
# total_aeronaves_envolvidas                 int64
# ocorrencia_saida_pista                    object
# dtype: object

# %%
schema = pa.DataFrameSchema(columns = {
    "codigo":pa.Column(pa.Int, required=False),
    "codigo_ocorrencia":pa.Column(pa.Int),
    "ocorrencia_cidade":pa.Column(pa.String),
    "ocorrencia_uf":pa.Column(pa.String, 
                              pa.Check.str_length(2,2)),
    "ocorrencia_dia":pa.Column(pa.DateTime),
    "ocorrencia_hora":pa.Column(pa.String, 
                                pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3])(:[0-5][0-9]){2}$'), 
                                nullable=True,),
})

# %%
schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /tmp/ipykernel_60453/994206330.py in <module>
# ----> 1 schema.validate(df)
#
# ~/.local/lib/python3.8/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     592                 check_results.append(isinstance(result, pd.DataFrame))
#     593             except errors.SchemaError as err:
# --> 594                 error_handler.collect_error("schema_component_check", err)
#     595             except errors.SchemaErrors as err:
#     596                 for schema_error_dict in err.schema_errors:
#
# ~/.local/lib/python3.8/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# ~/.local/lib/python3.8/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     584         for schema_component in schema_components:
#     585             try:
# --> 586                 result = schema_component(
#     587                     df_to_validate,
#     588                     lazy=lazy,
#
# ~/.local/lib/python3.8/site-packages/pandera/schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1824     ) -> Union[pd.DataFrame, pd.Series]:
#    1825         """Alias for ``validate`` method."""
# -> 1826         return self.validate(
#    1827             check_obj, head, tail, sample, random_state, lazy, inplace
#    1828         )
#
# ~/.local/lib/python3.8/site-packages/pandera/schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     212                     )
#     213             else:
# --> 214                 validate_column(check_obj, column_name)
#     215
#     216         return check_obj
#
# ~/.local/lib/python3.8/site-packages/pandera/schema_components.py in validate_column(check_obj, column_name)
#     185
#     186         def validate_column(check_obj, column_name):
# --> 187             super(Column, copy(self).set_name(column_name)).validate(
#     188                 check_obj,
#     189                 head,
#
# ~/.local/lib/python3.8/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1786                 )
#    1787             except errors.SchemaError as err:
# -> 1788                 error_handler.collect_error("dataframe_check", err)
#    1789             except Exception as err:  # pylint: disable=broad-except
#    1790                 # catch other exceptions that may occur when executing the
#
# ~/.local/lib/python3.8/site-packages/pandera/error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# ~/.local/lib/python3.8/site-packages/pandera/schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    1781             try:
#    1782                 check_results.append(
# -> 1783                     _handle_check_results(
#    1784                         self, check_index, check, check_obj, *check_args
#    1785                     )
#
# ~/.local/lib/python3.8/site-packages/pandera/schemas.py in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    2106             warnings.warn(error_msg, UserWarning)
#    2107             return True
# -> 2108         raise errors.SchemaError(
#    2109             schema,
#    2110             check_obj,
#
# SchemaError: <Schema Column(name=ocorrencia_uf, type=DataType(str))> failed element-wise validator 0:
# <Check str_length: str_length(2, 2)>
# failure cases:
#    index failure_case
# 0   2227          ***
