# %%
import pandas as pd
import pandera as pa

# %%
cenipa_dataset = "../../datasets/cenipa/ocorrencia_2010_2020.csv"
df = pd.read_csv(cenipa_dataset, 
                 delimiter=";", 
                 parse_dates=["ocorrencia_dia"],
                 dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
# [5 rows x 22 columns]

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[3]
# Out:
# codigo_ocorrencia                               39527
# codigo_ocorrencia1                              39527
# codigo_ocorrencia2                              39527
# codigo_ocorrencia3                              39527
# codigo_ocorrencia4                              39527
# ocorrencia_classificacao                     ACIDENTE
# ocorrencia_latitude                    -13.1066666667
# ocorrencia_longitude                   -55.9930555556
# ocorrencia_cidade                  LUCAS DO RIO VERDE
# ocorrencia_uf                                      MT
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             ****
# ocorrencia_dia                    2010-01-04 00:00:00
# ocorrencia_hora                              17:30:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero         A-539/CENIPA/2018
# divulgacao_relatorio_publicado                    SIM
# divulgacao_dia_publicacao                  2019-10-28
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 3, dtype: object

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
#
# [3 rows x 22 columns]

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              39789               39789               39789
# 40              39158               39158               39158
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               39789               39789                INCIDENTE
# 40               39158               39158                INCIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 NaN                  NaN  SÃO PEDRO DO SUL            RS
# 40                 ***                  ***             BELÉM            PA
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2010-01-10        21:30:00                            ***
# 40  ...     2010-01-28        16:00:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10                 NaN                         NaN
# 40          FINALIZADA                         NaN
#
#    divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 10                            NÃO                       NaN
# 40                            NÃO                       NaN
#
#    total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 10                   0                          1                     NÃO
# 40                   0                          1                     NÃO
#
# [2 rows x 22 columns]

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index("codigo_ocorrencia", inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# codigo_ocorrencia
# 40211                             ***                  ***
# 40349                             NaN                  NaN
# 40351                             NaN                  NaN
# 39527                  -13.1066666667       -55.9930555556
# 40324                             NaN                  NaN
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# codigo_ocorrencia                                                    ...
# 40211                  RIO DE JANEIRO            RJ          BRASIL  ...
# 40349                           BELÉM            PA          BRASIL  ...
# 40351                  RIO DE JANEIRO            RJ          BRASIL  ...
# 39527              LUCAS DO RIO VERDE            MT          BRASIL  ...
# 40324                         PELOTAS            RS          BRASIL  ...
#
#                   ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00
# 40349                 2010-01-03        11:05:00
# 40351                 2010-01-03        03:00:00
# 39527                 2010-01-04        17:30:00
# 40324                 2010-01-05        19:25:00
#
#                   investigacao_aeronave_liberada investigacao_status  \
# codigo_ocorrencia
# 40211                                        SIM          FINALIZADA
# 40349                                        SIM          FINALIZADA
# 40351                                        SIM          FINALIZADA
# 39527                                        SIM          FINALIZADA
# 40324                                        SIM          FINALIZADA
#
#                   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# codigo_ocorrencia
# 40211                                     ***                            NÃO
# 40349                                     NaN                            NÃO
# 40351                                     NaN                            NÃO
# 39527                       A-539/CENIPA/2018                            SIM
# 40324                                     NaN                            NÃO
#
#                   divulgacao_dia_publicacao total_recomendacoes  \
# codigo_ocorrencia
# 40211                                   NaN                   0
# 40349                                   NaN                   0
# 40351                                   NaN                   0
# 39527                            2019-10-28                   0
# 40324                                   NaN                   0
#
#                    total_aeronaves_envolvidas  ocorrencia_saida_pista
# codigo_ocorrencia
# 40211                                       1                     NÃO
# 40349                                       1                     NÃO
# 40351                                       1                     NÃO
# 39527                                       1                     NÃO
# 40324                                       1                     NÃO
#
# [5 rows x 21 columns]

# %%
df.loc[40349]
# Out:
# codigo_ocorrencia1                              40349
# codigo_ocorrencia2                              40349
# codigo_ocorrencia3                              40349
# codigo_ocorrencia4                              40349
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               NaN
# ocorrencia_longitude                              NaN
# ocorrencia_cidade                               BELÉM
# ocorrencia_uf                                      PA
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBBE
# ocorrencia_dia                    2010-01-03 00:00:00
# ocorrencia_hora                              11:05:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       NaN
# divulgacao_relatorio_publicado                    NÃO
# divulgacao_dia_publicacao                         NaN
# total_recomendacoes                                 0
# total_aeronaves_envolvidas                          1
# ocorrencia_saida_pista                            NÃO
# Name: 40349, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(5)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# 1                  NaN               BELÉM            PA          BRASIL  ...
# 2                  NaN      RIO DE JANEIRO            RJ          BRASIL  ...
# 3       -55.9930555556  LUCAS DO RIO VERDE            MT          BRASIL  ...
# 4                  NaN             PELOTAS            RS          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2010-01-03        12:00:00                            SIM
# 1     2010-01-03        11:05:00                            SIM
# 2     2010-01-03        03:00:00                            SIM
# 3     2010-01-04        17:30:00                            SIM
# 4     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
# 1                   0                           1                     NÃO
# 2                   0                           1                     NÃO
# 3                   0                           1                     NÃO
# 4                   0                           1                     NÃO
#
# [5 rows x 21 columns]

# %%
df.loc[0,"ocorrencia_latitude"] = ""
df.loc[1] = "teste"
df.loc[:,"ocorrencia_longitude"] = "teste2"
df.head(3)
# Out:
#   codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3 codigo_ocorrencia4  \
# 0              40211              40211              40211              40211
# 1              teste              teste              teste              teste
# 2              40351              40351              40351              40351
#
#   ocorrencia_classificacao ocorrencia_latitude ocorrencia_longitude  \
# 0                INCIDENTE                                   teste2
# 1                    teste               teste               teste2
# 2                INCIDENTE                 NaN               teste2
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...       ocorrencia_dia  \
# 0    RIO DE JANEIRO            RJ          BRASIL  ...  2010-01-03 00:00:00
# 1             teste         teste           teste  ...                teste
# 2    RIO DE JANEIRO            RJ          BRASIL  ...  2010-01-03 00:00:00
#
#   ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0        12:00:00                            SIM          FINALIZADA
# 1           teste                          teste               teste
# 2        03:00:00                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                       teste                          teste
# 2                         NaN                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                     teste               teste                      teste
# 2                       NaN                   0                          1
#
#   ocorrencia_saida_pista
# 0                    NÃO
# 1                  teste
# 2                    NÃO
#
# [3 rows x 21 columns]

# %%
df.loc[df.ocorrencia_uf == "SP", ["ocorrencia_classificacao"]] = 'GRAVE'
df.head()
# Out:
#   codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3 codigo_ocorrencia4  \
# 0              40211              40211              40211              40211
# 1              teste              teste              teste              teste
# 2              40351              40351              40351              40351
# 3              39527              39527              39527              39527
# 4              40324              40324              40324              40324
#
#   ocorrencia_classificacao ocorrencia_latitude ocorrencia_longitude  \
# 0                INCIDENTE                                   teste2
# 1                    teste               teste               teste2
# 2                INCIDENTE                 NaN               teste2
# 3                 ACIDENTE      -13.1066666667               teste2
# 4                INCIDENTE                 NaN               teste2
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...       ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ          BRASIL  ...  2010-01-03 00:00:00
# 1               teste         teste           teste  ...                teste
# 2      RIO DE JANEIRO            RJ          BRASIL  ...  2010-01-03 00:00:00
# 3  LUCAS DO RIO VERDE            MT          BRASIL  ...  2010-01-04 00:00:00
# 4             PELOTAS            RS          BRASIL  ...  2010-01-05 00:00:00
#
#   ocorrencia_hora investigacao_aeronave_liberada investigacao_status  \
# 0        12:00:00                            SIM          FINALIZADA
# 1           teste                          teste               teste
# 2        03:00:00                            SIM          FINALIZADA
# 3        17:30:00                            SIM          FINALIZADA
# 4        19:25:00                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                       teste                          teste
# 2                         NaN                            NÃO
# 3           A-539/CENIPA/2018                            SIM
# 4                         NaN                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                     teste               teste                      teste
# 2                       NaN                   0                          1
# 3                2019-10-28                   0                          1
# 4                       NaN                   0                          1
#
#   ocorrencia_saida_pista
# 0                    NÃO
# 1                  teste
# 2                    NÃO
# 3                    NÃO
# 4                    NÃO
#
# [5 rows x 21 columns]

# %%
df.loc[df.ocorrencia_uf == "SP"]
# Out:
#      codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3  \
# 11                40069              40069              40069
# 16                39809              39809              39809
# 18                39828              39828              39828
# 26                39847              39847              39847
# 27                39768              39768              39768
# ...                 ...                ...                ...
# 5704              79739              79739              79739
# 5705              79705              79705              79705
# 5715              79718              79718              79718
# 5742              79800              79800              79800
# 5747              79804              79804              79804
#
#      codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 11                40069                    GRAVE      -23.5069444444
# 16                39809                    GRAVE                 NaN
# 18                39828                    GRAVE                 ***
# 26                39847                    GRAVE                 NaN
# 27                39768                    GRAVE                 NaN
# ...                 ...                      ...                 ...
# 5704              79739                    GRAVE     -23.62611111111
# 5705              79705                    GRAVE          -23.483056
# 5715              79718                    GRAVE          -23.509174
# 5742              79800                    GRAVE          -23.506667
# 5747              79804                    GRAVE      -23.0069444444
#
#      ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# 11                 teste2         SÃO PAULO            SP          BRASIL
# 16                 teste2         SÃO PAULO            SP          BRASIL
# 18                 teste2            SANTOS            SP          BRASIL
# 26                 teste2          SOROCABA            SP          BRASIL
# 27                 teste2          CAMPINAS            SP          BRASIL
# ...                   ...               ...           ...             ...
# 5704               teste2         SÃO PAULO            SP          BRASIL
# 5705               teste2          SOROCABA            SP          BRASIL
# 5715               teste2         SÃO PAULO            SP          BRASIL
# 5742               teste2         SÃO PAULO            SP          BRASIL
# 5747               teste2          CAMPINAS            SP          BRASIL
#
#       ...       ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 11    ...  2010-01-10 00:00:00        14:50:00                            SIM
# 16    ...  2010-01-15 00:00:00        15:00:00                            ***
# 18    ...  2010-01-15 00:00:00        17:45:00                            ***
# 26    ...  2010-01-20 00:00:00        13:10:00                            ***
# 27    ...  2010-01-21 00:00:00        20:45:00                            ***
# ...   ...                  ...             ...                            ...
# 5704  ...  2020-12-03 00:00:00        14:42:00                            SIM
# 5705  ...  2020-12-04 00:00:00        15:30:00                            SIM
# 5715  ...  2020-12-11 00:00:00        13:50:00                            SIM
# 5742  ...  2020-12-28 00:00:00        10:15:00                            SIM
# 5747  ...  2020-12-29 00:00:00        19:00:00                            SIM
#
#      investigacao_status divulgacao_relatorio_numero  \
# 11            FINALIZADA           A-121/CENIPA/2012
# 16                   NaN                         NaN
# 18                   NaN                         NaN
# 26                   NaN                         NaN
# 27                   NaN                         NaN
# ...                  ...                         ...
# 5704               ATIVA          IG-144/CENIPA/2020
# 5705          FINALIZADA                         ***
# 5715          FINALIZADA                         ***
# 5742          FINALIZADA                         ***
# 5747          FINALIZADA                         ***
#
#      divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 11                              SIM                2012-11-19
# 16                              NÃO                       NaN
# 18                              NÃO                       NaN
# 26                              NÃO                       NaN
# 27                              NÃO                       NaN
# ...                             ...                       ...
# 5704                            NÃO                       NaN
# 5705                            NÃO                       NaN
# 5715                            NÃO                       NaN
# 5742                            NÃO                       NaN
# 5747                            NÃO                       NaN
#
#      total_recomendacoes total_aeronaves_envolvidas ocorrencia_saida_pista
# 11                     8                          1                    NÃO
# 16                     0                          1                    NÃO
# 18                     0                          1                    NÃO
# 26                     0                          1                    NÃO
# 27                     0                          1                    NÃO
# ...                  ...                        ...                    ...
# 5704                   0                          2                    NÃO
# 5705                   0                          1                    NÃO
# 5715                   0                          1                    SIM
# 5742                   0                          1                    NÃO
# 5747                   0                          1                    NÃO
#
# [1373 rows x 21 columns]

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
# [5 rows x 22 columns]

# %% [markdown]
# ocorrencia_uf
# **
#
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
#
# ocorrencia_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.replace(['**', '###!', '####', '***' ,'*****', 'NULL'], pd.NA, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                <NA>                 <NA>      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                        <NA>
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
# [5 rows x 22 columns]

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2293
# ocorrencia_longitude              2295
# ocorrencia_cidade                    0
# ocorrencia_uf                        1
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2349
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2482
# investigacao_status                340
# divulgacao_relatorio_numero       3800
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4258
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %%
df.fillna(0).isna().sum()
# Out:
# codigo_ocorrencia                 0
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# dtype: int64

# %%
df.dropna()
